# %% [markdown]
# # Operational Chroma Scan

# %%
import imageio
import pickle
import pandas as pd
import numpy as np
import PyNAFF as pnf
import scipy.io as sio 
import matplotlib.cm as cm
from math import log10, floor
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from scipy.optimize import curve_fit

# %%
plt.rcParams['figure.figsize'] = [5.0, 5.0]
plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 200

plt.rcParams['font.size'] = 10
plt.rcParams['legend.fontsize'] = 'small'
plt.rcParams['lines.linewidth'] = 1

# %% [markdown]
# ## Function declarations

# %%
def harmonic_fn(x, a, b, c, d):
    return a + b*np.cos(c + 2*np.pi*d*x)

# %%
def quadratic(x, a, m, c):
    return a*x**2 + x*m + c

# %%
def cubic(x, a, m, c, b):
    return a*x**2 + x*m + c + b*x**3

# %%
def Md_fit(x, a, b, c, d):
        return a + b*np.cos(c*x+d)

# %%
def Md_ramp_fit(x, a, b, c, d):
    return a + b*(x-1)*np.cos(c*(x-1)+d)

# %%
def round_sig(x, sig=2):
    return round(x, sig-int(floor(log10(abs(x))))-1)

# %%
def add_input_file(dd, filename, label):
	f = filename
	p = dict()
	sio.loadmat(f, mdict=p)
	dd[label] = p
	print '\tAdded output data from ', filename, '\t dictionary key: ', label
	return dd

# %% [markdown]
# # Load output data

# %%
num_sims = 15
dps = np.linspace(-2.5E-3, 2.5E-3, num_sims)

ddo = dict()

ddo = add_input_file(ddo, '03_01/output/output.mat', round_sig(dps[0]))
ddo = add_input_file(ddo, '03_02/output/output.mat', round_sig(dps[1]))
ddo = add_input_file(ddo, '03_03/output/output.mat', round_sig(dps[2]))
ddo = add_input_file(ddo, '03_04/output/output.mat', round_sig(dps[3]))
ddo = add_input_file(ddo, '03_05/output/output.mat', round_sig(dps[4]))
ddo = add_input_file(ddo, '03_06/output/output.mat', round_sig(dps[5]))
ddo = add_input_file(ddo, '03_07/output/output.mat', round_sig(dps[6]))
ddo = add_input_file(ddo, '03_08/output/output.mat', dps[7])
ddo = add_input_file(ddo, '03_09/output/output.mat', round_sig(dps[8]))
ddo = add_input_file(ddo, '03_10/output/output.mat', round_sig(dps[9]))
ddo = add_input_file(ddo, '03_11/output/output.mat', round_sig(dps[10]))
ddo = add_input_file(ddo, '03_12/output/output.mat', round_sig(dps[11]))
ddo = add_input_file(ddo, '03_13/output/output.mat', round_sig(dps[12]))
ddo = add_input_file(ddo, '03_14/output/output.mat', round_sig(dps[13]))
ddo = add_input_file(ddo, '03_15/output/output.mat', round_sig(dps[14]))
# Out:
# 	Added output data from  03_01/output/output.mat 	 dictionary key:  -0.0025
# 	Added output data from  03_02/output/output.mat 	 dictionary key:  -0.0021
# 	Added output data from  03_03/output/output.mat 	 dictionary key:  -0.0018
# 	Added output data from  03_04/output/output.mat 	 dictionary key:  -0.0014
# 	Added output data from  03_05/output/output.mat 	 dictionary key:  -0.0011
# 	Added output data from  03_06/output/output.mat 	 dictionary key:  -0.00071
# 	Added output data from  03_07/output/output.mat 	 dictionary key:  -0.00036
# 	Added output data from  03_08/output/output.mat 	 dictionary key:  0.0
# 	Added output data from  03_09/output/output.mat 	 dictionary key:  0.00036
# 	Added output data from  03_10/output/output.mat 	 dictionary key:  0.00071
# 	Added output data from  03_11/output/output.mat 	 dictionary key:  0.0011
# 	Added output data from  03_12/output/output.mat 	 dictionary key:  0.0014
# 	Added output data from  03_13/output/output.mat 	 dictionary key:  0.0018
# 	Added output data from  03_14/output/output.mat 	 dictionary key:  0.0021
# 	Added output data from  03_15/output/output.mat 	 dictionary key:  0.0025

# %% [markdown]
# # Plot and name parameters etc

# %%
save_folder = 'Plots/Operational/100/'
CO_offset = '100'

sc = 'NoSC'
legend_label = r'$\frac{\delta p}{p_0}$'
main_label = 'OP_Chroma'
main_label2 = main_label + '_zoom'
scaled_label = main_label + '_scaled'
turn_tot = 2200
zoom_turns = 30
turns = [0, 1, 10, 50, 100, 874, 2185, 2199]
betagamma = 2.492104532 * 0.9159915293879255

# %%
ddo[0].keys()
# Out:
# ['eps_z',
#  'D_x',
#  'D_y',
#  'kurtosis_yp_6sig',
#  'kurtosis_yp',
#  'mu_yp',
#  'kurtosis_z_6sig',
#  'eff_beta_y',
#  'eff_beta_x',
#  'eff_alpha_y',
#  'kurtosis_y_6sig',
#  'epsn_y',
#  'epsn_x',
#  'beta_y',
#  'beta_x',
#  'dpp_rms',
#  'sig_yp',
#  'min_dE',
#  'orbit_x_max',
#  'turn_time',
#  'n_mp',
#  'min_xp',
#  'orbit_x_min',
#  'kurtosis_y',
#  'kurtosis_xp_6sig',
#  'alpha_x',
#  'alpha_y',
#  'bunchlength',
#  '__header__',
#  'sig_xp',
#  'kurtosis_dE_6sig',
#  'max_xp',
#  'intensity',
#  'min_yp',
#  'sig_dE',
#  'min_x',
#  'min_y',
#  'mu_y',
#  'mu_x',
#  'cumulative_time',
#  'mean_yp',
#  'kurtosis_xp',
#  'eff_epsn_y',
#  'eff_epsn_x',
#  'mean_x',
#  'mean_y',
#  'mean_z',
#  'kurtosis_x_6sig',
#  '__version__',
#  'max_z',
#  'mu_dE',
#  'max_x',
#  'max_y',
#  'mean_dE',
#  'sig_z',
#  'sig_y',
#  'sig_x',
#  'max_yp',
#  'kurtosis_z',
#  'eff_alpha_x',
#  'kurtosis_x',
#  'mu_xp',
#  'turn_duration',
#  'mu_z',
#  'mean_xp',
#  'min_z',
#  'kurtosis_dE',
#  'orbit_y_max',
#  'orbit_y_min',
#  '__globals__',
#  'turn',
#  'max_dE',
#  'gamma']

# %%
parameter = 'mu_x'

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' Quadrupolar Tune CO_offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$\sqrt{\mu_x} = \sigma_x$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)

for key, value in sorted(ddo.iteritems()):
        ax1.plot(ddo[key]['turn'][0], np.sqrt(ddo[key][parameter][0])*1000, label=key, color=colors[c_it]);
        c_it = c_it + 1
        
ax1.legend(fontsize='small', loc=4, title=legend_label)
ax1.grid()
ax1.set_xlim(-1,30)

savename = save_folder + 'sig_x.png'
plt.tight_layout()
#plt.savefig(savename, dpi = 800);

# %% [markdown]
# # Save frequencies using different methods

# %%
qx_harmonic = []
qy_harmonic = []

qx_fft = []
qy_fft = []

qx_naff = []
qy_naff = []

# %%
parameter = 'sig_x'

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' harmonic fit CO_offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_x$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)
y_fine = np.array(range(0, 30000))*0.001
#print y_fine

for key, value in sorted(ddo.iteritems()):
#key=0

    y = np.array(range(0, 31))
    x = np.array(ddo[key][parameter][0]*1E3)

    mean_x = np.mean(x)    
    if mean_x < 0.0 :
        offset_min = 1.5 * np.mean(x)
        offset_max = 0.5 * np.mean(x)
    else:
        offset_min = 0.5 * np.mean(x)
        offset_max = 1.5 * np.mean(x)    

    amp_min = 0.5 * 0.999 * (np.max(x) - np.min(x))
    amp_max = 0.5 * 1.001 * (np.max(x) - np.min(x))

    freq_min = 0.0
    freq_max = 0.49

    popt, pcov = curve_fit(harmonic_fn, ddo[key]['turn'][0]+1, x, method = 'trf', bounds =((offset_min,amp_min,-np.inf,freq_min),(offset_max,amp_max,np.inf,freq_max)))

    print '\n Momentum Offset = ', key
    print ' Offset = ', popt[0], ' mm'
    print ' Amplitude = ', popt[1], ' mm'
    print ' Frequency = ', round(popt[3],4)
    print ' Phase offset = ', popt[2] / (2*np.pi)

    ax1.plot(y_fine, harmonic_fn(y_fine, popt[0], popt[1], popt[2], popt[3]), color=colors[c_it])
    lab_ = str(str(key) + r', $f_{\sigma}$ = ' + str(round(popt[3],4)))
    ax1.scatter(ddo[key]['turn'][0]+1, x, label=lab_, color=colors[c_it], marker='x');
    c_it = c_it + 1
    
    #qy_harmonic.append(popt[3])
        
ax1.legend(fontsize='small', loc=4, title=legend_label)
ax1.grid()
ax1.set_xlim(-1,30);
#ax1.set_ylim(-2,2);

savename = save_folder + 'qx_quadrupolar_harmonic.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
# Out:
#  Momentum Offset =  -0.0025
#  Offset =  3.2240197350394437  mm
#  Amplitude =  1.1924935986606875  mm
#  Frequency =  0.2185
#  Phase offset =  0.5063882859760311
#
#  Momentum Offset =  -0.0021
#  Offset =  3.225283052055694  mm
#  Amplitude =  1.1886345987349909  mm
#  Frequency =  0.2185
#  Phase offset =  0.5062057942549301
#
#  Momentum Offset =  -0.0018
#  Offset =  3.217330285246799  mm
#  Amplitude =  1.189864176396779  mm
#  Frequency =  0.2185
#  Phase offset =  0.5070064188553057
#
#  Momentum Offset =  -0.0014
#  Offset =  3.21761575178123  mm
#  Amplitude =  1.1906158071382174  mm
#  Frequency =  0.2185
#  Phase offset =  0.5058598126264127
#
#  Momentum Offset =  -0.0011
#  Offset =  3.221340294030295  mm
#  Amplitude =  1.1833399901519601  mm
#  Frequency =  0.2185
#  Phase offset =  0.5063363757397067
#
#  Momentum Offset =  -0.00071
#  Offset =  3.221147806553914  mm
#  Amplitude =  1.1897398280592055  mm
#  Frequency =  0.2185
#  Phase offset =  0.5057818090089778
#
#  Momentum Offset =  -0.00036
#  Offset =  3.2219267647472556  mm
#  Amplitude =  1.1885678749442186  mm
#  Frequency =  0.2185
#  Phase offset =  0.5068825138250518
#
#  Momentum Offset =  0.0
#  Offset =  3.214604778413543  mm
#  Amplitude =  1.181085749537989  mm
#  Frequency =  0.2185
#  Phase offset =  0.505601389773189
#
#  Momentum Offset =  0.00036
#  Offset =  3.216415457433667  mm
#  Amplitude =  1.1877654435923772  mm
#  Frequency =  0.2185
#  Phase offset =  0.5061994933222898
#
#  Momentum Offset =  0.00071
#  Offset =  3.223035869987827  mm
#  Amplitude =  1.1895604809622287  mm
#  Frequency =  0.2185
#  Phase offset =  0.5057003500751411
#
#  Momentum Offset =  0.0011
#  Offset =  3.2190011903147466  mm
#  Amplitude =  1.1875390355872164  mm
#  Frequency =  0.2185
#  Phase offset =  0.5054268252106613
#
#  Momentum Offset =  0.0014
#  Offset =  3.208125156937078  mm
#  Amplitude =  1.172203084786454  mm
#  Frequency =  0.2185
#  Phase offset =  0.5061858409851634
#
#  Momentum Offset =  0.0018
#  Offset =  3.2214070870609017  mm
#  Amplitude =  1.187967838990512  mm
#  Frequency =  0.2185
#  Phase offset =  0.5060490869225587
#
#  Momentum Offset =  0.0021
#  Offset =  3.2243682465250982  mm
#  Amplitude =  1.1919781740694877  mm
#  Frequency =  0.2185
#  Phase offset =  0.5051956709956329
#
#  Momentum Offset =  0.0025
#  Offset =  3.2187086064242174  mm
#  Amplitude =  1.1887129107169467  mm
#  Frequency =  0.2185
#  Phase offset =  0.5060231296702483

# %%
parameter = 'sig_y'

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' harmonic fit CO_offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$\sigma_y$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)
y_fine = np.array(range(0, 30000))*0.001
#print y_fine

for key, value in sorted(ddo.iteritems()):
#key=0

    y = np.array(range(0, 31))
    x = np.array(ddo[key][parameter][0]*1E3)

    mean_x = np.mean(x)
    if mean_x < 0.0 :
        offset_min = 1.5 * np.mean(x)
        offset_max = 0.5 * np.mean(x)
    else:
        offset_min = 0.5 * np.mean(x)
        offset_max = 1.5 * np.mean(x)    

    amp_min = 0.5 * 0.999 * (np.max(x) - np.min(x))
    amp_max = 0.5 * 1.001 * (np.max(x) - np.min(x))

    freq_min = 0.15001
    freq_max = 0.2499

    popt, pcov = curve_fit(harmonic_fn, ddo[key]['turn'][0]+1, x, method = 'trf', bounds =((offset_min,amp_min,-np.inf,freq_min),(offset_max,amp_max,np.inf,freq_max)))

    print '\n Momentum Offset = ', key
    print ' Offset = ', popt[0], ' mm'
    print ' Amplitude = ', popt[1], ' mm'
    print ' Frequency = ', round(popt[3],4)
    print ' Phase offset = ', popt[2] / (2*np.pi)

    ax1.plot(y_fine, harmonic_fn(y_fine, popt[0], popt[1], popt[2], popt[3]), color=colors[c_it])
    lab_ = str(str(key) + r', $f_{\sigma}$ = ' + str(round(popt[3],4)))
    ax1.scatter(ddo[key]['turn'][0]+1, x, label=lab_, color=colors[c_it], marker='x');
    c_it = c_it + 1
    
    #qy_harmonic.append(popt[3])
        
ax1.legend(fontsize='small', loc=4, title=legend_label)
ax1.grid()
ax1.set_xlim(-1,30);
#ax1.set_ylim(-2,2);

savename = save_folder + 'qy_quadrupolar_harmonic.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
# Out:
#  Momentum Offset =  -0.0025
#  Offset =  2.970160623197207  mm
#  Amplitude =  0.01646208087796921  mm
#  Frequency =  0.2056
#  Phase offset =  0.15766094335982528
#
#  Momentum Offset =  -0.0021
#  Offset =  2.9819835469994684  mm
#  Amplitude =  0.02582622181515871  mm
#  Frequency =  0.206
#  Phase offset =  0.15565840490124516
#
#  Momentum Offset =  -0.0018
#  Offset =  2.963367847791736  mm
#  Amplitude =  0.027639130890287668  mm
#  Frequency =  0.2058
#  Phase offset =  0.15461422785429102
#
#  Momentum Offset =  -0.0014
#  Offset =  2.9709922021683997  mm
#  Amplitude =  0.018494211848988786  mm
#  Frequency =  0.2061
#  Phase offset =  0.1571552511157057
#
#  Momentum Offset =  -0.0011
#  Offset =  2.967155556801393  mm
#  Amplitude =  0.021959186316064402  mm
#  Frequency =  0.206
#  Phase offset =  0.15444655036139338
#
#  Momentum Offset =  -0.00071
#  Offset =  2.9738215809993593  mm
#  Amplitude =  0.022521824079143413  mm
#  Frequency =  0.2061
#  Phase offset =  0.15507502732388068
#
#  Momentum Offset =  -0.00036
#  Offset =  2.9663427125758606  mm
#  Amplitude =  0.017454802829416135  mm
#  Frequency =  0.2053
#  Phase offset =  0.1573095835888496
#
#  Momentum Offset =  0.0
#  Offset =  2.9770155055350402  mm
#  Amplitude =  0.026594119592180873  mm
#  Frequency =  0.2057
#  Phase offset =  0.16233393004427413
#
#  Momentum Offset =  0.00036
#  Offset =  2.9784931877077474  mm
#  Amplitude =  0.021052414962488657  mm
#  Frequency =  0.2055
#  Phase offset =  0.15724442588006138
#
#  Momentum Offset =  0.00071
#  Offset =  2.979450082688889  mm
#  Amplitude =  0.023616502142401234  mm
#  Frequency =  0.2058
#  Phase offset =  0.15477561964361636
#
#  Momentum Offset =  0.0011
#  Offset =  2.974193878870355  mm
#  Amplitude =  0.021268670201464696  mm
#  Frequency =  0.2057
#  Phase offset =  0.15702699198274758
#
#  Momentum Offset =  0.0014
#  Offset =  2.975771829718341  mm
#  Amplitude =  0.02391817491939713  mm
#  Frequency =  0.206
#  Phase offset =  0.15675227230693897
#
#  Momentum Offset =  0.0018
#  Offset =  2.97505201544416  mm
#  Amplitude =  0.025029604546581194  mm
#  Frequency =  0.2059
#  Phase offset =  0.15460757705326972
#
#  Momentum Offset =  0.0021
#  Offset =  2.9673157261206238  mm
#  Amplitude =  0.0197451711592001  mm
#  Frequency =  0.2058
#  Phase offset =  0.1655901904254408
#
#  Momentum Offset =  0.0025
#  Offset =  2.9682642171142137  mm
#  Amplitude =  0.02060649863818016  mm
#  Frequency =  0.2057
#  Phase offset =  0.15773281203814302

# %%
parameter = 'mean_x'

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' harmonic fit CO_offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$<x>$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)
y_fine = np.array(range(0, 30000))*0.001
#print y_fine

for key, value in sorted(ddo.iteritems()):
#key=0

    y = np.array(range(0, 31))
    x = np.array(ddo[key][parameter][0]*1E3)

    mean_x = np.mean(x)
    if mean_x < 0.0 :
        offset_min = 1.5 * np.mean(x)
        offset_max = 0.5 * np.mean(x)
    else:
        offset_min = 0.5 * np.mean(x)
        offset_max = 1.5 * np.mean(x)    

    amp_min = 0.5 * 0.999 * (np.max(x) - np.min(x))
    amp_max = 0.5 * 1.001 * (np.max(x) - np.min(x))

    freq_min = 0.149
    freq_max = 0.249

    popt, pcov = curve_fit(harmonic_fn, ddo[key]['turn'][0]+1, x, method = 'trf', bounds =((offset_min,amp_min,-np.inf,freq_min),(offset_max,amp_max,np.inf,freq_max)))

    print '\n Momentum Offset = ', key
    print ' Offset = ', popt[0], ' mm'
    print ' Amplitude = ', popt[1], ' mm'
    print ' Frequency = ', round(popt[3],4)
    print ' Phase offset = ', popt[2] / (2*np.pi)

    ax1.plot(y_fine, harmonic_fn(y_fine, popt[0], popt[1], popt[2], popt[3]), color=colors[c_it])
    lab_ = str(str(key) + r', $f_{\sigma}$ = ' + str(round(popt[3],4)))
    ax1.scatter(ddo[key]['turn'][0]+1, x, label=lab_, color=colors[c_it], marker='x');
    c_it = c_it + 1
    
    qx_harmonic.append(popt[3])
        
ax1.legend(fontsize='small', loc=4, title=legend_label)
ax1.grid()
ax1.set_xlim(-1,30);
#ax1.set_ylim(-2,2);

savename = save_folder + 'qx_harmonic.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
# Out:
#  Momentum Offset =  -0.0025
#  Offset =  -0.6592071225026308  mm
#  Amplitude =  0.2244680323110967  mm
#  Frequency =  0.215
#  Phase offset =  0.9027989047537625
#
#  Momentum Offset =  -0.0021
#  Offset =  -0.6519373478576055  mm
#  Amplitude =  0.23333755104390091  mm
#  Frequency =  0.2163
#  Phase offset =  0.8547461500581303
#
#  Momentum Offset =  -0.0018
#  Offset =  -0.6500025699915254  mm
#  Amplitude =  0.21518285566137224  mm
#  Frequency =  0.2155
#  Phase offset =  0.8789300872713912
#
#  Momentum Offset =  -0.0014
#  Offset =  -0.6494006087587246  mm
#  Amplitude =  0.22247325352524303  mm
#  Frequency =  0.2159
#  Phase offset =  0.8686956556630233
#
#  Momentum Offset =  -0.0011
#  Offset =  -0.6504044353823777  mm
#  Amplitude =  0.2329323213659655  mm
#  Frequency =  0.2159
#  Phase offset =  0.8733999055512645
#
#  Momentum Offset =  -0.00071
#  Offset =  -0.6587939949664073  mm
#  Amplitude =  0.2106393183632326  mm
#  Frequency =  0.2149
#  Phase offset =  0.8980381542457849
#
#  Momentum Offset =  -0.00036
#  Offset =  -0.6560004382910338  mm
#  Amplitude =  0.22883128802506386  mm
#  Frequency =  0.2159
#  Phase offset =  0.8695103730099585
#
#  Momentum Offset =  0.0
#  Offset =  -0.662419821944156  mm
#  Amplitude =  0.2225766853825535  mm
#  Frequency =  0.2161
#  Phase offset =  0.8594477411509366
#
#  Momentum Offset =  0.00036
#  Offset =  -0.6563281502157289  mm
#  Amplitude =  0.2210962851504468  mm
#  Frequency =  0.2155
#  Phase offset =  0.8838605006969701
#
#  Momentum Offset =  0.00071
#  Offset =  -0.6386895113043266  mm
#  Amplitude =  0.23246150843048494  mm
#  Frequency =  0.2169
#  Phase offset =  0.8308311857813583
#
#  Momentum Offset =  0.0011
#  Offset =  -0.6552644448558156  mm
#  Amplitude =  0.22468127008776514  mm
#  Frequency =  0.2163
#  Phase offset =  0.854200123766342
#
#  Momentum Offset =  0.0014
#  Offset =  -0.6638146976291807  mm
#  Amplitude =  0.2133784005567196  mm
#  Frequency =  0.2153
#  Phase offset =  0.8876594520231095
#
#  Momentum Offset =  0.0018
#  Offset =  -0.655056949888301  mm
#  Amplitude =  0.21588195109178482  mm
#  Frequency =  0.2156
#  Phase offset =  0.875547309369405
#
#  Momentum Offset =  0.0021
#  Offset =  -0.6547471762527249  mm
#  Amplitude =  0.2242478215556616  mm
#  Frequency =  0.2156
#  Phase offset =  0.8774487986604642
#
#  Momentum Offset =  0.0025
#  Offset =  -0.6610866371232055  mm
#  Amplitude =  0.22882091432373816  mm
#  Frequency =  0.2154
#  Phase offset =  0.8894761805053194

# %%
parameter = 'mean_y'

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' harmonic fit CO_offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$<y>$ [mm]');
ax1.set_xlabel('Turn [-]');

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)
y_fine = np.array(range(0, 30000))*0.001
#print y_fine

for key, value in sorted(ddo.iteritems()):
#key=0

    y = np.array(range(0, 31))
    x = np.array(ddo[key][parameter][0]*1E3)

    mean_x = np.mean(x)
    if mean_x < 0.0 :
        offset_min = 1.5 * np.mean(x)
        offset_max = 0.5 * np.mean(x)
    else:
        offset_min = 0.5 * np.mean(x)
        offset_max = 1.5 * np.mean(x)    

    amp_min = 0.5 * 0.999 * (np.max(x) - np.min(x))
    amp_max = 0.5 * 1.001 * (np.max(x) - np.min(x))

    freq_min = 0.2199
    freq_max = 0.2499

    popt, pcov = curve_fit(harmonic_fn, ddo[key]['turn'][0]+1, x, method = 'trf', bounds =((offset_min,amp_min,-np.inf,freq_min),(offset_max,amp_max,np.inf,freq_max)))

    print '\n Momentum Offset = ', key
    print ' Offset = ', popt[0], ' mm'
    print ' Amplitude = ', popt[1], ' mm'
    print ' Frequency = ', round(popt[3],4)
    print ' Phase offset = ', popt[2] / (2*np.pi)

    ax1.plot(y_fine, harmonic_fn(y_fine, popt[0], popt[1], popt[2], popt[3]), color=colors[c_it])
    lab_ = str(str(key) + r', $f_{\sigma}$ = ' + str(round(popt[3],4)))
    ax1.scatter(ddo[key]['turn'][0]+1, x, label=lab_, color=colors[c_it], marker='x');
    c_it = c_it + 1
    
    qy_harmonic.append(popt[3])
        
ax1.legend(fontsize='small', loc=4, title=legend_label)
ax1.grid()
ax1.set_xlim(-1,30);
#ax1.set_ylim(-2,2);

savename = save_folder + 'qy_harmonic.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
# Out:
#  Momentum Offset =  -0.0025
#  Offset =  4.3852422000382114e-05  mm
#  Amplitude =  0.011495267948240838  mm
#  Frequency =  0.2445
#  Phase offset =  0.047928952635649606
#
#  Momentum Offset =  -0.0021
#  Offset =  -0.0002020663934321812  mm
#  Amplitude =  0.013395379945060484  mm
#  Frequency =  0.2415
#  Phase offset =  0.4766548260629883
#
#  Momentum Offset =  -0.0018
#  Offset =  0.00018101710385129874  mm
#  Amplitude =  0.014440014729216317  mm
#  Frequency =  0.2432
#  Phase offset =  0.005059799943469564
#
#  Momentum Offset =  -0.0014
#  Offset =  8.875516673003554e-05  mm
#  Amplitude =  0.005952397226380709  mm
#  Frequency =  0.2489
#  Phase offset =  0.6328795838624165
#
#  Momentum Offset =  -0.0011
#  Offset =  2.7560124193315985e-05  mm
#  Amplitude =  0.009227388197189544  mm
#  Frequency =  0.2447
#  Phase offset =  0.0584930523974581
#
#  Momentum Offset =  -0.00071
#  Offset =  -0.0003268978904820623  mm
#  Amplitude =  0.01764436045554973  mm
#  Frequency =  0.244
#  Phase offset =  0.25181310879786417
#
#  Momentum Offset =  -0.00036
#  Offset =  -0.00029196872560768736  mm
#  Amplitude =  0.013446817111315686  mm
#  Frequency =  0.2405
#  Phase offset =  0.35080980677660795
#
#  Momentum Offset =  0.0
#  Offset =  0.00041181714112226896  mm
#  Amplitude =  0.03165880173587106  mm
#  Frequency =  0.2428
#  Phase offset =  0.009865964535173497
#
#  Momentum Offset =  0.00036
#  Offset =  -0.0005703426412851643  mm
#  Amplitude =  0.02547390880076498  mm
#  Frequency =  0.242
#  Phase offset =  0.3251822846897115
#
#  Momentum Offset =  0.00071
#  Offset =  -0.00034160066457490087  mm
#  Amplitude =  0.015082186910088738  mm
#  Frequency =  0.2429
#  Phase offset =  0.37952943751430007
#
#  Momentum Offset =  0.0011
#  Offset =  1.186206548340995e-05  mm
#  Amplitude =  0.00469236206874283  mm
#  Frequency =  0.2448
#  Phase offset =  0.05830889600192559
#
#  Momentum Offset =  0.0014
#  Offset =  0.00018221856065290192  mm
#  Amplitude =  0.016679943925468985  mm
#  Frequency =  0.2441
#  Phase offset =  -0.007976773721034666
#
#  Momentum Offset =  0.0018
#  Offset =  -0.00037488118899466495  mm
#  Amplitude =  0.019433468368662957  mm
#  Frequency =  0.2425
#  Phase offset =  0.2717296072400336
#
#  Momentum Offset =  0.0021
#  Offset =  1.2095364197201616e-05  mm
#  Amplitude =  0.010470759175151813  mm
#  Frequency =  0.2411
#  Phase offset =  0.13216070787083145
#
#  Momentum Offset =  0.0025
#  Offset =  0.0001396733834717508  mm
#  Amplitude =  0.016147499546892274  mm
#  Frequency =  0.2437
#  Phase offset =  0.6550901611136084

# %%
# Store envelope oscillation frequencies
f_sig_y = []

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' mean_y  CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$|A_{DFT}|$ [-]');
ax1.set_xlabel(r'$f_{\sigma_{y}}$ [-]');

N_turns = 31

hann=np.hanning(N_turns)
freq_h = np.fft.rfftfreq(N_turns)

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)

for key, value in sorted(ddo.iteritems()):

    ampl_h = np.abs(np.fft.rfft(ddo[key]['mean_y'][0]*hann))
    n = np.argmax(ampl_h[4:]) + 4
    popt, pcov = curve_fit(quadratic,freq_h[n-1:n+2],ampl_h[n-1:n+2])
    f_range = np.arange(freq_h[n-1],freq_h[n+1],0.001)
    f_max = -1*popt[1]/(2*popt[0])
    a_max = quadratic(f_max,popt[0],popt[1],popt[2])
    lab_ =  r'$\frac{\delta p}{p_0}=$' + str(key) + ' $f_\sigma = $ '+ str(round(f_max,4))
    plt.semilogy(freq_h,ampl_h,'b', label = lab_, color=colors[c_it], ls='--')
    plt.semilogy([f_max, f_max], [0, a_max],'--k')
    plt.semilogy(f_range,quadratic(f_range,popt[0],popt[1],popt[2]), color=colors[c_it])
    f_max = -1*popt[1]/(2*popt[0])
    c_it = c_it + 1
        
    f_sig_y.append(f_max)
    qy_fft.append(f_max)
    
ax1.legend(loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'y_fft.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
# Out:
# /usr/lib64/python2.7/site-packages/scipy/optimize/minpack.py:785: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
fig1 = plt.figure(facecolor='w', edgecolor='k');
ax1 = fig1.add_subplot(111);

tit = main_label + ' ' + sc + ' FFT mean_y CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_y$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

dps = np.linspace(-2.5E-3, 2.5E-3, num_sims)

ax1.scatter(dps, f_sig_y);
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
#ax1.set_ylim(0.215, 0.245);

savename = save_folder + 'qy.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %%
# Store envelope oscillation frequencies
f_sig_x = []

fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' FFT mean_x' + parameter + ' CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$|A_{DFT}|$ [-]');
ax1.set_xlabel(r'$f_{\sigma_{x}}$ [-]');

N_turns = 31

hann=np.hanning(N_turns)
freq_h = np.fft.rfftfreq(N_turns)

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)

for key, value in sorted(ddo.iteritems()):

    ampl_h = np.abs(np.fft.rfft(ddo[key]['mean_x'][0]*hann))
    n = np.argmax(ampl_h[4:]) + 4
    popt, pcov = curve_fit(quadratic,freq_h[n-1:n+2],ampl_h[n-1:n+2])
    f_range = np.arange(freq_h[n-1],freq_h[n+1],0.001)
    f_max = -1*popt[1]/(2*popt[0])
    a_max = quadratic(f_max,popt[0],popt[1],popt[2])
    lab_ =  r'$\frac{\delta p}{p_0}=$' + str(key) + ' $f_\sigma = $ '+ str(round(f_max,4))
    plt.semilogy(freq_h,ampl_h,'b', label = lab_, color=colors[c_it], ls='--')
    plt.semilogy([f_max, f_max], [0, a_max],'--k')
    plt.semilogy(f_range,quadratic(f_range,popt[0],popt[1],popt[2]), color=colors[c_it])
    f_max = -1*popt[1]/(2*popt[0])
    c_it = c_it + 1
        
    f_sig_x.append(f_max)
    qx_fft.append(f_max)
    
ax1.legend(fontsize='small', loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'x_fft.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %%
fig1 = plt.figure(facecolor='w', edgecolor='k');
ax1 = fig1.add_subplot(111);

tit = main_label + ' ' + sc + ' FFT mean_x  CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_x$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

dps = np.linspace(-2.5E-3, 2.5E-3, num_sims)
ax1.scatter(dps, f_sig_x);
ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
ax1.set_ylim(0.205, 0.225);

savename = save_folder + 'qx.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %% [markdown]
# # Calculate tunes using NAFF

# %%
parameter = 'mean_y'
        
fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_y$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
#ax1.set_ylim(0.215, 0.245);

skiptrns= 4
N_turns = 31 - skiptrns

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)

for key, value in sorted(ddo.iteritems()):    
    y = (ddo[key][parameter][0]-np.mean(ddo[key][parameter][0]))
    try:
        if key == 0.0: 
            skiptrns = 3
            N_turns = 31 - skiptrns
        elif key == 0.001: 
            skiptrns = 3
            N_turns = 31 - skiptrns
        elif key == 0.002: 
            skiptrns = 3
            N_turns = 31 - skiptrns
        elif key == 0.003: 
            skiptrns = 3
            N_turns = 31 - skiptrns
        #print skiptrns
        freq = pnf.naff(y, turns=N_turns, nterms=1, skipTurns=skiptrns, getFullSpectrum=False, window=1)[0][1]
        lab_ =  r'$\frac{\delta p}{p_0}=$' + str(key) + ' $f_\sigma = $ '+ str(round(freq,4)) 
        ax1.scatter(float(key), freq, label=str(lab_))
    except IndexError:
        continue 

        
    f_sig_x.append(freq)
    qy_naff.append(freq)
    
ax1.legend(fontsize='small', loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'qy_naff.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %%
parameter = 'mean_x'
        
fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' ' + parameter + ' CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_x$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
#ax1.set_ylim(0.205, 0.225);

skiptrns= 6
N_turns = 31 - skiptrns

colors = cm.rainbow(np.linspace(0, 1, len(ddo.keys())))
c_it = int(0)

for key, value in sorted(ddo.iteritems()):    
    y = (ddo[key][parameter][0]-np.mean(ddo[key][parameter][0]))
    try:
        freq = pnf.naff(y, turns=N_turns, nterms=1, skipTurns=skiptrns, getFullSpectrum=False, window=1)[0][1]
        lab_ =  r'$\frac{\delta p}{p_0}=$' + str(key) + ' $f_\sigma = $ '+ str(round(freq,4)) 
        ax1.scatter(float(key), freq, label=str(lab_))
    except IndexError:
        continue 
        
    f_sig_x.append(freq)
    qx_naff.append(freq)
    
ax1.legend(fontsize='small', loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'qx_naff.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %% [markdown]
# # Compare different calculated tunes

# %%
fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' H tunes CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_x$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
ax1.set_ylim(0.215, 0.235);

dps = np.linspace(-2.5E-3, 2.5E-3, num_sims)

ax1.scatter(dps, qx_naff, label='NAFF', color='r', marker='x');
ax1.scatter(dps, qx_fft, label='FFT', color='b', marker='x');
ax1.scatter(dps, qx_harmonic, label='Harmonic', color='g', marker='x');

ax1.legend(fontsize='small', loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'qx_cf.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);

# %%
fig1 = plt.figure(facecolor='w', edgecolor='k')
ax1 = fig1.add_subplot(111)

tit = main_label + ' ' + sc + ' V tunes CO offset = ' + CO_offset
ax1.set_title(tit);

ax1.set_ylabel(r'$f_{\sigma} = q_y$ [-]');
ax1.set_xlabel(r'$\frac{\delta p}{p}$ [-]');

ax1.grid(lw=0.5, ls=':');
ax1.set_xlim(-3.1E-3,3.1E-3);
#ax1.set_ylim(0.205, 0.225);

dps = np.linspace(-2.5E-3, 2.5E-3, num_sims)

ax1.scatter(dps, qy_naff, label='NAFF', color='r', marker='x');
ax1.scatter(dps, qy_fft, label='FFT', color='b', marker='x');
ax1.scatter(dps, qy_harmonic, label='Harmonic', color='g', marker='x');

ax1.legend(fontsize='small', loc=4)
ax1.grid(lw=0.5, ls=':')

savename = save_folder + 'qy_cf.png'
plt.tight_layout()
plt.savefig(savename, dpi = 800);
